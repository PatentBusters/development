# %%
import os
import pandas as pd
import xml.etree.ElementTree as ET
from pprint import pprint
import numpy as np

print(os.getcwd())
# Out:
# /home/linus/Mistral/development

# %%
# Fonction pour convertir un élément XML en dictionnaire
def xml_to_dict(element):
    item = {}
    for child in element:
        if len(child):
            item[child.tag] = xml_to_dict(child)
        else:
            item[child.tag] = child.text
    return item

# %%
# Preprocess dict
def preprocess_dict(d, parent_key=''):
    items = []
    for k, v in d.items():
        new_key = f'{parent_key}.{k}' if parent_key else k
        if isinstance(v, dict):
            items.extend(preprocess_dict(v, new_key).items())
        else:
            items.append((new_key, v))
    return dict(items)

# %%
relevant_keys = [
    'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country',
    'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number',
    'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind',
    'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date',
    'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum',
    'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature',
    'fr-bibliographic-data.fr-application-reference.document-id.country',
    'fr-bibliographic-data.fr-application-reference.document-id.doc-number',
    'fr-bibliographic-data.fr-application-reference.document-id.date',
    'fr-bibliographic-data.invention-title',
    'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname',
    'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1',
    'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city',
    'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode',
    'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country',
    'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name',
    'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name',
    'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1',
    'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city',
    'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode',
    'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country',
    'fr-bibliographic-data.parties.agents.agent.addressbook.orgname',
    'fr-bibliographic-data.parties.agents.agent.addressbook.address.address-1',
    'fr-bibliographic-data.parties.agents.agent.addressbook.address.city',
    'fr-bibliographic-data.parties.agents.agent.addressbook.address.postcode',
    'fr-bibliographic-data.parties.agents.agent.addressbook.address.country',
    'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname',
    'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1',
    'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city',
    'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode',
    'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country',
    'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text',
    'fr-bibliographic-data.language-of-filing',
    'abstract.p',
    'fr-patent-life.references-cited.citation.patcit.text',
    'fr-patent-life.references-cited.citation.patcit.document-id.country',
    'fr-patent-life.references-cited.citation.patcit.document-id.doc-number',
    'fr-patent-life.references-cited.citation.patcit.document-id.date',
    'fr-patent-life.fr-date-availability.fr-last-fee-payement.date',
    'fr-patent-life.fr-date-availability.fr-next-fee-payement.date',
    'fr-patent-life.fr-date-availability.fr-date-search-completed.date',
    'fr-patent-life.fr-date-availability.fr-date-search-completed.fr-bopinum'
]

def extract_relevant_info(d):
  """
  Returns a dictionary containing only relevant attributes with a value of None
  if not found

  Args:
  d (dict): The dictionary to fetch the values from update

  Returns:
  relevant (dict)
  """

  relevant = {}
  for key in relevant_keys:
      if key in d:
        relevant[key] = d[key]
      else:
        relevant[key] = "None"

  return relevant

example_dict = {'some-key': 'some-value'}
example_dict = extract_relevant_info(example_dict)

print(example_dict)
# Out:
# {'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'None', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': 'None', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'None', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': 'None', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': 'None', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'None', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'None', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': 'None', 'fr-bibliographic-data.fr-application-reference.document-id.date': 'None', 'fr-bibliographic-data.invention-title': 'None', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'None', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': 'None', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'None', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': 'None', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'None', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'None', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'None', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': 'None', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'None', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': 'None', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'None', 'fr-bibliographic-data.parties.agents.agent.addressbook.orgname': 'None', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.address-1': 'None', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.city': 'None', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.postcode': 'None', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.country': 'None', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'None', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': 'None', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': 'None', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': 'None', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country': 'None', 'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'None', 'fr-bibliographic-data.language-of-filing': 'None', 'abstract.p': 'None', 'fr-patent-life.references-cited.citation.patcit.text': 'None', 'fr-patent-life.references-cited.citation.patcit.document-id.country': 'None', 'fr-patent-life.references-cited.citation.patcit.document-id.doc-number': 'None', 'fr-patent-life.references-cited.citation.patcit.document-id.date': 'None', 'fr-patent-life.fr-date-availability.fr-last-fee-payement.date': 'None', 'fr-patent-life.fr-date-availability.fr-next-fee-payement.date': 'None', 'fr-patent-life.fr-date-availability.fr-date-search-completed.date': 'None', 'fr-patent-life.fr-date-availability.fr-date-search-completed.fr-bopinum': 'None'}

# %%
all_data = []

for folder in os.listdir("patents"):
    folder_path = os.path.join("patents", folder)
    if os.path.isdir(folder_path):
        for file in os.listdir(folder_path):
            file_path = os.path.join(folder_path, file)
            if os.path.isfile(file_path) and file.endswith(".xml"):
                print(file_path)
                tree = ET.parse(file_path)
                root = tree.getroot()
                patent_info = xml_to_dict(root)
                data = preprocess_dict(patent_info)
                print(data)
                data = extract_relevant_info(data)
                values = list(data.values())
                all_data.append(values)

print(len(all_data))
# Out:
# patents/2024_05/3138508.xml
# {'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3138508', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240202', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-05', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2207731', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220727', 'fr-bibliographic-data.invention-title': 'DISPOSITIF D’AÉRATION ESCAMOTABLE POUR UN SYSTÈME', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'PSA AUTOMOBILES SA', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.iid': '542065479', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': "2-10 Boulevard de l'Europe", 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'Poissy', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '78300', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'DE BEAUMONT', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'TANCREDE', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': None, 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'SURESNES', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '92150', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'FR', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'STELLANTIS AUTO SAS', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.iid': '542065479', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': "2-10 boulevard de l'Europe", 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': 'POISSY', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': '78300', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country': 'FR', 'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'F24F  13/065       20220101AFI20220922BHFR        ', 'fr-bibliographic-data.language-of-filing': 'fr', 'abstract.p': '\n    Un dispositif d’aération (DA) comprend un mécanisme d’orientation (MO) installé dans une paroi (PS) d’un système (S) et pouvant être placé dans différentes positions pour orienter dans l’espace un flux d’air qui l’alimente, et un organe de commande (OC) propre, en cas d’actionnement par un usager, à contrôler la position du mécanisme d’orientation (MO). Ce mécanisme d’orientation (MO) comprend une pièce rotative (PR) comprenant au moins une ouverture (O1) propre à être traversée par le flux d’air, et propre à être entraînée en rotation par rapport à la paroi (PS) entre une position escamotée, dans laquelle chaque ouverture (O1) est invisible par l’usager, et une position maximale dans laquelle le flux d’air sort de chaque ouverture (O1) avec une orientation ayant une première contribution maximale dans un premier plan prédéfini.\n    Figure à publier avec l’abrégé : Fig. 3\n  ', 'fr-patent-life.references-cited.citation.patcit.text': 'DE 10 2004 060386 A1 (FAURECIA INNENRAUM\nSYS GMBH [DE]) 29 juin 2006 (2006-06-29)', 'fr-patent-life.references-cited.citation.patcit.document-id.country': 'DE', 'fr-patent-life.references-cited.citation.patcit.document-id.doc-number': 'DE-102004060386-A1', 'fr-patent-life.references-cited.citation.patcit.document-id.date': '20060629', 'fr- ...
# patents/2024_05/3138561.xml
# {'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3138561', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240202', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-05', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2207650', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220726', 'fr-bibliographic-data.invention-title': 'ENSEMBLE ELECTRIQUE POUR SECURISER UN RESEAU ELECTRIQUE HAUTE TENSION D’UN VEHICULE AUTOMOBILE ELECTRIFIE', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'PSA AUTOMOBILES SA', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.iid': '542065479', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': "2-10 Boulevard de l'Europe", 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'Poissy', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '78300', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'JEAN', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'KAMILLE', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': None, 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'FONTAINEBLEAU', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '77300', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'FR', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'STELLANTIS AUTO SAS', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.iid': '542065479', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': "2-10 boulevard de l'Europe", 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': 'POISSY', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': '78300', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country': 'FR', 'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'B60L   3/00        20220101ALI20221005BHFR        ', 'fr-bibliographic-data.language-of-filing': 'fr', 'abstract.p': '\n    L’invention concerne un ensemble électrique (1) configuré pour empêcher une ouverture intempestive d’un réseau électrique haute tension (RHT) d’un véhicule automobile, l’ensemble électrique (1) comportant une batterie électrique de traction (11) reliée au réseau électrique haute tension (RHT), au moins un contacteur (CT+, CT-) de sécurité configuré pour coupler ou découpler la batterie électrique de traction (11) au réseau électrique haute tension (RHT), un organe de sécurité (17) alimenté par la batterie électrique basse tension (15) et relié à l’au moins un contacteur (CT+, CT-) afin de contrôler une alimentation électrique de l’au moins un contacteur (CT+, CT-) pour autoriser une fermeture ou une ouverture du réseau électrique haute tension (RHT), et un dispositif électrique (16) configuré pour maintenir l’au moins un contacteur (CT+, CT-) fermé pendant une durée de référence en cas d’ouverture intempestive de l’organe de sécurité (17).\n    Figure 1 \n  ', 'fr-patent-life.references-cited.citation.patcit.text': 'EP 3 385 108 A1 (LG CHEMICAL LTD [KR])\n10 octobre 2018 (2018-10-10)', 'fr-patent-life.references-cited.citation.patcit.document-id.country': 'EP', 'fr-patent-life.references-cited.citation.patcit.document- ...
# patents/2024_05/3138566.xml
# {'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3138566', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240202', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-05', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2207972', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220801', 'fr-bibliographic-data.invention-title': 'Module lumineux intégrant une diode électroluminescente organique flexible', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'Valeo Vision', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.iid': '950344333', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': '34 RUE SAINT-ANDRÉ', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'BOBIGNY CEDEX', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '93012', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'Jimenez Rodriguez', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'Raul', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': None, 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'BOBIGNY', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '93012', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.agents.agent.addressbook.orgname': 'AQUINOV', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.address-1': 'Allée de la forestière', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.city': 'Beychac et Caillau', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.postcode': '33750', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.country': 'FR', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'Valeo Vision', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.iid': '950344333', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': '34 RUE SAINT-ANDRÉ', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': 'BOBIGNY CEDEX', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': '93012', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country': 'FR', 'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'F21S  43/145       20220101ALI20221116BHFR        ', 'fr-bibliographic-data.language-of-filing': 'fr', 'abstract.p': '\n    L’invention concerne un module lumineux (1) d’un dispositif d’éclairage et/ou de signalisation de véhicule automobile, comportant\xa0une OLED flexible (2) montée sur un substrat transparent (3) comportant une couche d’interconnexion électrique\xa0; un support (4) de OLED flexible agencé pour conformer au moins une partie de l’OLED flexible et le substrat transparent selon une forme prédéterminée, l’OLED flexible étant fixée au support au moyen d’un adhésif\xa0(51) ; une carte de circuit imprimé flexible (6) ; caractérisé en ce que le substrat transparent comporte une portion (32) dépassant de l’OLED et faisant face à une portion (43) du support, en ce que la carte de circuit imprimé flexible est reliée électriquement à la couche d’interconnexion au niveau de cette portion du substrat transparent et en ce que la carte de circuit impr ...
# patents/2024_05/3138488.xml
# {'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3138488', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240202', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-05', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2207735', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220727', 'fr-bibliographic-data.invention-title': 'DISTRIBUTEUR A JOINT INCORPORE, ET PROCEDE DE REALISATION\xa0', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'Bontaz Centre R&D', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.iid': '789489705', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': 'Impasse des chênes Z.I des Valignons', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'MARNAZ', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '74460', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'MIRALLES', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'ERIC', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': None, 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'ARENTHON', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '74800', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.agents.agent.addressbook.orgname': 'BREVALEX', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.address-1': '22 Avenue Doyen Louis Weil', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.city': 'GRENOBLE CEDEX 01', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.postcode': '38024', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.country': 'FR', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'Bontaz Centre R&D', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.iid': '789489705', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': 'Impasse des chênes Z.I des Valignons', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': 'MARNAZ', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': '74460', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country': 'FR', 'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'F16K   5/04        20220101AFI20220930BHFR        ', 'fr-bibliographic-data.language-of-filing': 'fr', 'abstract.p': "\n    L'invention concerne un distributeur rotatif hydraulique comportant un boîtier (2) et un noyau (4), ledit boîtier (2) comprenant une paroi latérale (8), deux parois d’extrémité (6, 10) délimitant une chambre hydraulique, dans laquelle est logé le noyau (4) apte à tourner dans ladite chambre autour d’un axe (XX’) de rotation, au moins un orifice d’alimentation (11), et au moins un orifice de sortie (12, 20), le noyau (4) comportant une surface latérale (32), une ouverture d’entrée (18), au moins une sortie latérale (34) et un conduit (38) ou une chambre qui relie l’ouverture d’entrée (18) et la sortie latérale et qui permet une alimentation de chacun desdits orifices de sortie (12, 20) en fonction de la position angulaire du noyau dans le boîtier, le noyau comportant en outre au moins un joint d’étanchéité inamovible,  ...
# patents/2024_05/3138285.xml
# {'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3138285', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240202', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-05', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2207865', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220729', 'fr-bibliographic-data.invention-title': 'Revêtement non-fluoré hybride PAEK/résine silicone', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'SEB S.A.', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.iid': '300349636', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': '112 chemin du Moulin Carron Campus SEB', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'ECULLY', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '69130', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'TANGUY', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'PERRINE', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': None, 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'ECULLY CEDEX', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '69134', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.agents.agent.addressbook.orgname': 'REGIMBEAU', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.address-1': '20, rue de Chazelles', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.city': 'PARIS CEDEX 17', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.postcode': '75847', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.country': 'FR', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'SEB S.A.', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.iid': '300349636', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': '112 chemin du Moulin Carron Campus SEB', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': 'ECULLY', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': '69130', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country': 'FR', 'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'B32B  15/08        20220101ALI20221103BHFR        ', 'fr-bibliographic-data.language-of-filing': 'fr', 'abstract.p': '\n    La présente invention concerne un élément de cuisson revêtu (1) pour article culinaire ou appareil électrique de cuisson, comportant un substrat métallique (2) revêtu sur au moins une face (2a) par au moins les couches suivantes et dans cet ordre à partir du substrat métallique 2)\xa0:\n    (3a) sous-couche dure poreuse constituée d’une ou plusieurs polyétherarylcétones (PEAK) et leurs mélanges, éventuellement de charges, éventuellement moins de 3\xa0% en poids d’additifs par rapport au poids de ladite sous-couche dure et éventuellement moins de 3\xa0% en poids d’agent(s) colorant(s) par rapport au poids de ladite sous-couche dure, \n    (3b) éventuellement, une ou plusieurs couche(s) intermédiaire(s) constituée(s) d’un ou plusieurs agent(s) colorant(s) et éventuellement \n    d’une ou plusieurs résine(s) silicone, et/oud’un ou plusieurs polymèr ...
# patents/2024_05/3138550.xml
# {'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3138550', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240202', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-05', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2207938', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220729', 'fr-bibliographic-data.invention-title': "Dispositif de surveillance d'opération industrielle", 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'ERAMET', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.iid': '632045381', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': '10 boulevard de Grenelle', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'Paris', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '75015', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'BOCZSZUK', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'Pierre', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': None, 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'Paris', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '75015', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.agents.agent.addressbook.orgname': 'Cabinet NETTER', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.address-1': '36 avenue Hoche', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.city': 'PARIS', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.postcode': '75008', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.country': 'FR', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'ERAMET', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.iid': '632045381', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': '10 boulevard de Grenelle', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': 'Paris', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': '75015', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country': 'FR', 'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'G06V  10/82        20220101ALI20221107BHFR        ', 'fr-bibliographic-data.language-of-filing': 'fr', 'abstract.p': "\n    Dispositif de surveillance d'opération industrielle\n    Un dispositif de surveillance d'opération industrielle comprend un carter (10) sensiblement étanche logeant une source d'acquisition d'images et/ou de vidéos\xa0(4) et un ordinateur (6). Le dispositif (2) est agencé pour déterminer des images de surveillance à partir de la source d'acquisition d'images et/ou de vidéos (4), l'ordinateur (6) est à refroidissement passif et est agencé pour exécuter une séquence d'apprentissage de normalité d'une scène d'un site d'opération industrielle à surveiller dont les données de sortie sont utilisées par une séquence de surveillance d'opération industrielle, l'ordinateur (6) est agencé, pour une scène donnée d'un site d'opération industrielle à surveiller, pour mettre en œuvre la séquence d'apprentissage de normalité en utilisant un réseau de neurones convolutif (8) pour réseau de neurones à transfer ...
# patents/2024_05/3138336.xml
# {'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3138336', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240202', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-05', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2207755', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220728', 'fr-bibliographic-data.invention-title': 'Procédé d’obtention d’une couronne annulaire métallique', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'SAFRAN AIRCRAFT ENGINES', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.iid': '414815217', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': '2, boulevard du Général Martial Valin', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'PARIS', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '75015', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'LECONTE', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'Gilbert, Michel, Marin', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': None, 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'MOISSY CRAMAYEL CEDEX', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '77550', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.agents.agent.addressbook.orgname': 'Ernest GUTMANN - Yves PLASSERAUD SAS', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.address-1': "Chez Plasseraud IP  66, rue de la Chaussée d'Antin", 'fr-bibliographic-data.parties.agents.agent.addressbook.address.city': 'PARIS', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.postcode': '75009', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.country': 'FR', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'SAFRAN AIRCRAFT ENGINES', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.iid': '414815217', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': '2, boulevard du Général Martial Valin', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': 'PARIS', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': '75015', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country': 'FR', 'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'B21D  53/16        20220101ALI20221031BHFR        ', 'fr-bibliographic-data.language-of-filing': 'fr', 'abstract.p': '\n    Procédé d’obtention d’une couronne métallique d’axe longitudinal, le procédé comprenant les étapes de\xa0:a) fourniture d’un anneau métallique (10) d’axe longitudinal (A), l’anneau (10) comprenant deux parois annulaires cylindriques radialement interne (12) et externe (14)\xa0;b) usinage des parois annulaires radialement interne (12) et externe (14) de manière à obtenir un renflement annulaire radialement interne (52) et un renflement annulaire radialement externe (62) ; c) réalisation d’un laminage circulaire droit sur lesdits renflements annulaires radialement interne (52) et externe (62).\n    Figure de l’abrégé\xa0: Figure 6\n  ', 'fr-patent-life.references-cited.citation.patcit.text': 'FR 3 017 060 A1 (SNECMA [FR])\n7 août 2015 (2015-08-0 ...
# patents/2024_05/3138277.xml
# {'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3138277', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240202', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-05', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2207648', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220726', 'fr-bibliographic-data.invention-title': 'Ensemble de présentation de produits comprenant des moyens permettant d’éliminer la glace, et son procédé de mise en œuvre', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'ARECO FINANCES ET TECHNOLOGIE - ARFITEC', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.iid': '479576449', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': '114 chemin de Saint Marc', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'GRASSE', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '06130', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'GSCHWIND', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'Michel', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': None, 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'PLACASSIER', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '06130', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.agents.agent.addressbook.orgname': 'IXAS CONSEIL', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.address-1': '22 avenue René Cassin', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.city': 'LYON', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.postcode': '69009', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.country': 'FR', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'ARECO FINANCES ET TECHNOLOGIE - ARFITEC', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.iid': '479576449', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': '114 chemin de Saint Marc', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': 'GRASSE', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': '06130', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country': 'FR', 'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'A47F   3/04        20220101AFI20220923BHFR        ', 'fr-bibliographic-data.language-of-filing': 'fr', 'abstract.p': '\n    Cet ensemble de présentation à la vente de produits, destinés à être conservés à une température contrôlée, comprend au moins un étalage (1 – 4) et un système d’alimentation (7) en liquide, notamment en eau potable, comportant au moins une ligne d’alimentation (72 – 75) apte à être connectée avec une source (200) dudit liquide, en particulier un réseau d’eau potable. \n    Chaque ligne alimente un organe de diffusion de liquide (6), placé au-dessus de la zone de réception de l’étalage en vue de l’élimination de la couche de glace présente sur la zone de réception, alors que des moyens de commande (9, 90, 92 - 95) sont configurés pour alimenter le liquide uniquement pendant une durée prédéfinie.\n    L’invention permet d’éliminer, de manière simple  ...
# patents/2024_05/3138460.xml
# {'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3138460', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240202', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-05', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2207726', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220727', 'fr-bibliographic-data.invention-title': 'BOITE DE RESERVATION POURVUE D’UNE PARTIE AIMANTEE', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'SIIB FRANCE', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.iid': '815379961', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': '7 Rue des Acilloux', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': "COURNON-D'AUVERGNE", 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '63800', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'AUCOUTURIER', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'René', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': None, 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'CHATEL-GUYON', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '63140', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.agents.agent.addressbook.orgname': 'ABSAROKA', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.address-1': '5 Chemin sous Vignoux', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.city': "BEAUREGARD L'EVEQUE", 'fr-bibliographic-data.parties.agents.agent.addressbook.address.postcode': '63116', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.country': 'FR', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'SIIB FRANCE', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.iid': '815379961', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': '7 Rue des Acilloux', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': "COURNON-D'AUVERGNE", 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': '63800', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country': 'FR', 'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'E04G  15/06        20220101AFI20220921BHFR        ', 'fr-bibliographic-data.language-of-filing': 'fr', 'abstract.p': '\n    L’invention concerne une boite de réservation (1) adaptée pour ménager un volume de réception de câbles et conduits dans une paroi en béton d’un bâtiment, caractérisée en ce que la boite de réservation (1) est ouverte sur au moins une (2) de ses faces et adaptée pour être solidarisée de manière réversible à un organe de liaison (3) pourvu d’au moins une partie aimantée, ladite partie aimanté étant adaptée pour réaliser une liaison magnétique amovible avec une zone métallique d’au moins un élément de coffrage de ladite paroi en béton du bâtiment.\n    Figure à publier avec l’abrégé\xa0: Fig. 1 \n  ', 'fr-patent-life.references-cited.citation.patcit.text': 'FR 2 754 291 A1 (ALOMBARD SA [FR])\n10 avril 1998 (1998-04-10)', 'fr-patent-life.references-cited.citation.patcit.document-id.country': 'FR', 'fr-patent-life.references-cited.citation.patcit.docum ...
# patents/2024_05/3138475.xml
# {'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3138475', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240202', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-05', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2207859', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220729', 'fr-bibliographic-data.invention-title': 'SYSTEME ET PROCEDE DE DETECTION DE COLMATAGE D’UN CLAPET ANTIRETOUR DE CHARGE PARTIELLE D’UN MOTEUR THERMIQUE, VEHICULE COMPRENANT UN TEL SYSTEME', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'PSA AUTOMOBILES SA', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.iid': '542065479', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': "2-10 Boulevard de l'Europe", 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'Poissy', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '78300', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'KEIM', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'MARION', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': None, 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'VOISINS LE BRETONNEUX', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '78960', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'FR', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'STELLANTIS AUTO SAS', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.iid': '542065479', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': "2-10 boulevard de l'Europe", 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': 'POISSY', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': '78300', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country': 'FR', 'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'F02D  41/14        20220101ALI20221010BHFR        ', 'fr-bibliographic-data.language-of-filing': 'fr', 'abstract.p': '\n    L’invention concerne un système de détection de colmatage d’un clapet antiretour amont (V1) d’un moteur thermique de véhicule automobile.\n    Le moteur thermique comprend\xa0:- une valve de régulation de pression (RV) dans un déshuileur (D) d’une culasse (C2)\xa0;- un clapet antiretour amont (V1) disposé dans le déshuileur (D), au niveau d’un retour interne (R) vers un tube d’admission (TA),- un clapet antiretour aval (V2) connecté à une ligne secondaire de ventilation des gaz (LG) issue de la culasse (C2).\n    Selon l’invention, le système de détection comprend\xa0:- un premier et un deuxième capteurs de pression absolue (AP1, AP2) respectivement pour l’amont du carter (C1) et la culasse (C2).\n    Le diagnostic de blocage est fait sur la base des pressions des capteurs (AP1, AP2), et d’une perte de charge.\n    L’invention concerne également un procédé et véhicule sur la base d’un tel système.\n    Figure 1\n  ', 'fr-patent-life.references-cited.citation.patcit.text': 'FR 3 124 232 A1 (PSA AUTOMOBILES SA)\n23 décembre 2022 (2022-12-23)', 'fr-patent-life.references-cited.citation.patcit.document-id.country': 'FR', 'fr-patent-life.references-cited.citation.patcit.documen ...
# patents/2024_05/3138425.xml
# {'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3138425', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240202', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-05', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2308156', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20230728', 'fr-bibliographic-data.invention-title': 'BLANC DE PRUSSE (PW) ENROBÉ ET PROCÉDÉ DE PRÉPARATION ET UTILISATION DE CELUI-CI', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'HUNAN BRUNP RECYCLING TECHNOLOGY CO., LTD.', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': 'No. 508 East Jinning Road Hi-Tech Zone, Ningxiang Changsha City', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'HUNAN PROVINCE', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '410600', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'CN', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'RUAN', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'Dingshan', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': None, 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'FOSHAN CITY, GUANGDONG PROVINCE', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '528137', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'CN', 'fr-bibliographic-data.parties.agents.agent.addressbook.orgname': 'CASALONGA', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.address-1': '31 Rue de Fleurus', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.city': 'PARIS-6E-ARRONDISSEMENT', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.postcode': '75006', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.country': 'FR', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'HUNAN BRUNP RECYCLING TECHNOLOGY CO., LTD.', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': 'No. 508 East Jinning Road Hi-Tech Zone, Ningxiang Changsha City', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': 'HUNAN PROVINCE', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': '410600', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country': 'CN', 'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'H01M   4/58        20230101ALI20231114BHFR        ', 'fr-bibliographic-data.language-of-filing': 'fr', 'fr-bibliographic-data.fr-priority-claims.fr-priority-claim.country': 'CN', 'fr-bibliographic-data.fr-priority-claims.fr-priority-claim.doc-number': '202210914516.1', 'fr-bibliographic-data.fr-priority-claims.fr-priority-claim.date': '20220729', 'abstract.p': '\n    La présente invention concerne le domaine technique des nouvelles batteries de stockage d’énergie, et décrit le blanc de Prusse (PW) enrobé et un procédé de préparation et une utilisation de celui-ci. Le Blanc de Prusse enrobé a pour formule chimique KxNa2-xAFe(CN)6 et comprend un noyau de Na2AFe(CN)6 et une couche d’enrobage de K2AFe(CN)6\xa0; où x va de 0,06 à 0,6 et A est au moins un élément choisi dans le groupe constitué de Ni2+, Co2+, Mn2+ et Fe2+.\n    Figure pour l’abrégé\xa0: figure 2\n  ', 'fr-patent-life.fr-date-availability.fr-next-fee-payement.date': '20240 ...
# patents/2024_05/3138315.xml
# ...
# patents/2024_01/3137441.xml
# {'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3137441', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240105', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-01', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2206509', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220629', 'fr-bibliographic-data.invention-title': 'Installation et procédé de liquéfaction d’hydrogène', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': "L'AIR LIQUIDE, SOCIETE ANONYME POUR L'ETUDE ET L'EXPLOITATION DES PROCEDES GEORGES CLAUDE", 'fr-bibliographic-data.parties.applicants.applicant.addressbook.iid': '552096281', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': "75 Quai d'Orsay", 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'PARIS', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '75007', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'PLAYS', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'Thibault', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': None, 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'JOUY-EN-JOSAS', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '78350', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.agents.agent.addressbook.orgname': "L'AIR LIQUIDE, SOCIETE ANONYME", 'fr-bibliographic-data.parties.agents.agent.addressbook.address.address-1': "75 Quai d'Orsay", 'fr-bibliographic-data.parties.agents.agent.addressbook.address.city': 'PARIS', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.postcode': '75321', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.country': 'FR', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': "L'AIR LIQUIDE, SOCIETE ANONYME POUR L'ETUDE ET L'EXPLOITATION DES PROCEDES GEORGES CLAUDE", 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.iid': '552096281', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': "75 Quai d'Orsay", 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': 'PARIS', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': '75007', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country': 'FR', 'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'C01B   3/00        20220101ALI20220831BHFR        ', 'fr-bibliographic-data.language-of-filing': 'fr', 'abstract.p': '\n    L’invention concerne une installation de liquéfaction d’hydrogène comprenant un circuit (3) d’hydrogène à refroidir, un ensemble d’échangeur(s) (4, 5, 6, 7, 8) de chaleur en échange thermique avec le circuit (3) d’hydrogène à refroidir, un système (9) de refroidissement comprenant un réfrigérateur à cycle de réfrigération d’un premier gaz de cycle comprenant de l’hélium et/ou de l’hydrogène, le circuit (3) d’hydrogène à refroidir comprenant au moins une section (12) de catalyse pour assurer une conversion de l’hydrogène ortho en hydrogène para, le circuit (3) d’hydrogène à refroidir comprenant en outre une première portion (13) de dérivation d’au moins une section (12) de catalyse, l’extrémité aval (23) du circuit (3) d’hydr ...
# patents/2024_01/3137420.xml
# {'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3137420', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240105', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-01', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2206668', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220630', 'fr-bibliographic-data.invention-title': 'Machine hydraulique comprenant une came et des pistons', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'POCLAIN HYDRAULICS INDUSTRIE', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.iid': '414781823', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': 'Route de Compiègne', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'VERBERIE', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '60410', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'GRAUX', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'Nicolas', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': None, 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'VERBERIE', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '60410', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.agents.agent.addressbook.orgname': 'REGIMBEAU', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.address-1': '20, rue de Chazelles', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.city': 'PARIS CEDEX 17', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.postcode': '75847', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.country': 'FR', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'POCLAIN HYDRAULICS INDUSTRIE', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.iid': '414781823', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': 'Route de Compiègne', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': 'VERBERIE', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': '60410', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country': 'FR', 'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'G01B   7/16        20220101ALI20220831BHFR        ', 'fr-bibliographic-data.language-of-filing': 'fr', 'abstract.p': '\n    La machine hydraulique (1) comprend\xa0:\n    - une came (14) présentant une face externe cylindrique (30) et un axe principal (X-X), et\n    - au moins une jauge (40) rigidement fixée à la face et agencée pour détecter une sollicitation de la face et/ou une variation d’une forme de la face.\n    Figure de l’abrégé\xa0: Fig. 3\n  ', 'fr-patent-life.references-cited.citation.patcit.text': 'US 10 295 418 B1 (HOLLAND ERIC [US])\n21 mai 2019 (2019-05-21)', 'fr-patent-life.references-cited.citation.patcit.document-id.country': 'US', 'fr-patent-life.references-cited.citation.patcit.document-id.doc-number': 'US-10295418-B1', 'fr-patent-life.references-cited.citation.patcit.document-id.date': '20190521', 'fr-patent-life.fr-date-availability.fr-last-fee-payement.date': '20230512', 'fr-patent-life.fr-date-availability.fr-next-fee-payement.date': '20240 ...
# patents/2024_01/3137506.xml
# {'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3137506', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240105', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-01', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2306805', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20230628', 'fr-bibliographic-data.invention-title': 'PROCÉDÉ DE PRÉPARATION D’UN MATÉRIAU EN CARBONE DUR À HAUTE PERFORMANCE ET SON UTILISATION', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'HUNAN BRUNP EV RECYCLING CO., LTD.', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': 'No. 018 Jinsha East Road, Jinzhou New District Changsha,', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'Hunan', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '410600', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'CN', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'RUAN', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'Dingshan', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': None, 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'Guangdong', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '528137', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'CN', 'fr-bibliographic-data.parties.agents.agent.addressbook.orgname': 'CABINET GERMAIN ET MAUREAU', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.address-1': '12 rue Boileau', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.city': 'LYON', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.postcode': '69006', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.country': 'FR', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'HUNAN BRUNP EV RECYCLING CO., LTD.', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': 'No. 018 Jinsha East Road, Jinzhou New District Changsha,', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': 'Hunan', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': '410600', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country': 'CN', 'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'H01M  10/054       20230101ALI20231011BHFR        ', 'fr-bibliographic-data.language-of-filing': 'fr', 'fr-bibliographic-data.fr-priority-claims.fr-priority-claim.country': 'CN', 'fr-bibliographic-data.fr-priority-claims.fr-priority-claim.doc-number': '202210758315.7', 'fr-bibliographic-data.fr-priority-claims.fr-priority-claim.date': '20220630', 'abstract.p': '\n    PROCÉDÉ DE PRÉPARATION D’UN MATÉRIAU EN CARBONE DUR À HAUTE PERFORMANCE ET SON UTILISATION\n    La présente demande divulgue un procédé de préparation d’un matériau en carbone dur à haute performance et son utilisation. L’amidon, le phosphate et l’eau sont mélangés pour l’imprégnation, et le matériau imprégné est séché pour obtenir de l’amidon post-imprégné, et l’amidon post-imprégné est soumis à un traitement thermique sous atmosphère inerte pour obtenir des microsphères de carbone à base d’amidon, et un gaz mixte de dioxyde de carbone et d’un gaz inerte est introduit dans les microsphères de carbone à base d’amidon pour la réaction ...
# patents/2024_01/3137277.xml
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
patentsDataFrame = pd.DataFrame(all_data, columns=relevant_keys)
patentsDataFrame = patentsDataFrame.fillna("None")
patentsDataFrame.head(5)
# patentsDataFrame.columns
# Out:
#   fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country  \
# 0                                                 FR
# 1                                                 FR
# 2                                                 FR
# 3                                                 FR
# 4                                                 FR
#
#   fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number  \
# 0                                            3138508
# 1                                            3138561
# 2                                            3138566
# 3                                            3138488
# 4                                            3138285
#
#   fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind  \
# 0                                                 A1
# 1                                                 A1
# 2                                                 A1
# 3                                                 A1
# 4                                                 A1
#
#   fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date  \
# 0                                           20240202
# 1                                           20240202
# 2                                           20240202
# 3                                           20240202
# 4                                           20240202
#
#   fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum  \
# 0                                            2024-05
# 1                                            2024-05
# 2                                            2024-05
# 3                                            2024-05
# 4                                            2024-05
#
#   fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature  \
# 0                                  Demande française
# 1                                  Demande française
# 2                                  Demande française
# 3                                  Demande française
# 4                                  Demande française
#
#   fr-bibliographic-data.fr-application-reference.document-id.country  \
# 0                                                 FR
# 1                                                 FR
# 2                                                 FR
# 3                                                 FR
# 4                                                 FR
#
#   fr-bibliographic-data.fr-application-reference.document-id.doc-number  \
# 0                                            2207731
# 1                                            2207650
# 2                                            2207972
# 3                                            2207735
# 4                                            2207865
#
#   fr-bibliographic-data.fr-application-reference.document-id.date  \
# 0                                           20220727
# 1                                           20220726
# 2                                           20220801
# 3                                           20220727
# 4                                           20220729
#
#                fr-bibliographic-data.invention-title  ...  \
# 0  DISPOSITIF D’AÉRATION ESCAMOTABLE POUR UN SYSTÈME  ...
# 1  ENSEMBLE ELECTRIQUE POUR SECURISER UN RESEAU E...  ...
# 2  Module lumineux intégrant une diode électrolum...  ...
# 3  DISTRIBUTEUR A JOINT INCORPORE, ET PROCEDE DE ...  ...
# 4  Revêtement non-fluoré hybride PAEK/résine sili...  ...
#
#   fr-bibliographic-data.language-of-filing  \
# 0                                       fr
# 1                                       fr
# 2                                       fr
# 3                                       fr
# 4                                       fr
#
#                                           abstract.p  \
# 0  \n    Un dispositif d’aération (DA) comprend u...
# 1  \n    L’invention concerne un ensemble électri...
# 2  \n    L’invention concerne un module lumineux ...
# 3  \n    L'invention concerne un distributeur rot...
# 4  \n    La présente invention concerne un élémen...
#
#   fr-patent-life.references-cited.citation.patcit.text  \
# 0  DE 10 2004 060386 A1 (FAURECIA INNENRAUM\nSYS ...
# 1  EP 3 385 108 A1 (LG CHEMICAL LTD [KR])\n10 oct...
# 2  US 2013/128199 A1 (YAMAZAKI SHUNPEI [JP]\nET A...
# 3  DE 20 2016 105607 U1 (GRÜNING & LOSKE GMBH\n[D...
# 4  FR 2 784 459 A1 (SEB SA [FR])\n14 avril 2000 (...
#
#   fr-patent-life.references-cited.citation.patcit.document-id.country  \
# 0                                                 DE
# 1                                                 EP
# 2                                                 US
# 3                                                 DE
# 4                                                 FR
#
#   fr-patent-life.references-cited.citation.patcit.document-id.doc-number  \
# 0                                 DE-102004060386-A1
# 1                                      EP-3385108-A1
# 2                                   US-2013128199-A1
# 3                                 DE-202016105607-U1
# 4                                      FR-2784459-A1
#
#   fr-patent-life.references-cited.citation.patcit.document-id.date  \
# 0                                           20060629
# 1                                           20181010
# 2                                           20130523
# 3                                           20180109
# 4                                           20000414
#
#   fr-patent-life.fr-date-availability.fr-last-fee-payement.date  \
# 0                                           20230621
# 1                                           20230621
# 2                                           20230828
# 3                                           20230728
# 4                                           20230727
#
#   fr-patent-life.fr-date-availability.fr-next-fee-payement.date  \
# 0                                           20240731
# 1                                           20240731
# 2                                           20240902
# 3                                           20240731
# 4                                           20240731
#
#   fr-patent-life.fr-date-availability.fr-date-search-completed.date  \
# 0                                           20240202
# 1                                           20240202
# 2                                           20240202
# 3                                           20240202
# 4                                           20240202
#
#   fr-patent-life.fr-date-availability.fr-date-search-completed.fr-bopinum
# 0                                            2024-05
# 1                                            2024-05
# 2                                            2024-05
# 3                                            2024-05
# 4                                            2024-05
#
# [5 rows x 42 columns]

# %%
patentsDataFrame.shape
# Out:
# (1344, 42)

# %%
! pip install -U --quiet langchain_community tiktoken langchain-core langchain-mistralai langchainhub chromadb langchain langgraph tavily-python
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 4.31.5 requires urllib3~=2.0, but you have urllib3 1.26.18 which is incompatible.
# socid-extractor 0.0.23 requires python-dateutil>=2.8.1, but you have python-dateutil 2.7.3 which is incompatible.
# transformers 4.35.0 requires tokenizers<0.15,>=0.14, but you have tokenizers 0.19.1 which is incompatible.

# %%
import os
os.environ['TOKENIZERS_PARALLELISM'] = 'true'
os.environ['MISTRAL_API_KEY'] = 'SbEwlTZ5lCgKTjMB0rWe8jhf2k7syJl3'
os.environ['TAVILY_API_KEY'] = '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'
os.environ['GROK_API_KEY'] = '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'

# %%
import os
os.environ['TOKENIZERS_PARALLELISM'] = 'true'
mistral_api_key = os.getenv("MISTRAL_API_KEY") # Ensure this is set
grok_api_key = os.getenv("GROK_API_KEY")

# %%
tavily_api_key = os.getenv("TAVILY_API_KEY") # Ensure this is set

# %%
os.environ['LANGCHAIN_TRACING_V2'] = 'true'
os.environ['LANGCHAIN_ENDPOINT'] = 'https://api.smith.langchain.com'
os.environ['LANGCHAIN_API_KEY'] = "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"
os.environ['HF_TOKEN'] = "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"

# %%
from langchain_core.documents.base import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import Chroma
from langchain_mistralai import MistralAIEmbeddings

if 'abstract.p' in relevant_keys:
  relevant_keys.remove('abstract.p')

docs_list = [Document(page_content=row['abstract.p'],
                       metadata={k: row[k] for k in relevant_keys})
             for index, row in patentsDataFrame.iterrows()]

text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size=250, chunk_overlap=0
)
doc_splits = text_splitter.split_documents(docs_list)

# Add to vectorDB
vectorstore = Chroma.from_documents(
    documents=doc_splits,
    collection_name="rag-chroma",
    embedding=MistralAIEmbeddings(),
)
# Out:
# /home/linus/.local/lib/python3.10/site-packages/langchain_mistralai/embeddings.py:105: UserWarning: Could not download mistral tokenizer from Huggingface for calculating batch sizes. Set a Huggingface token via the HF_TOKEN environment variable to download the real tokenizer. Falling back to a dummy tokenizer that uses `len()`.
#   warnings.warn(

# %%
retriever = vectorstore.as_retriever(search_type="mmr", search_kwargs={"k": 10})

# %%
pprint(docs_list[:10])
# Out:
# [Document(page_content='\n    Un dispositif d’aération (DA) comprend un mécanisme d’orientation (MO) installé dans une paroi (PS) d’un système (S) et pouvant être placé dans différentes positions pour orienter dans l’espace un flux d’air qui l’alimente, et un organe de commande (OC) propre, en cas d’actionnement par un usager, à contrôler la position du mécanisme d’orientation (MO). Ce mécanisme d’orientation (MO) comprend une pièce rotative (PR) comprenant au moins une ouverture (O1) propre à être traversée par le flux d’air, et propre à être entraînée en rotation par rapport à la paroi (PS) entre une position escamotée, dans laquelle chaque ouverture (O1) est invisible par l’usager, et une position maximale dans laquelle le flux d’air sort de chaque ouverture (O1) avec une orientation ayant une première contribution maximale dans un premier plan prédéfini.\n    Figure à publier avec l’abrégé : Fig. 3\n  ', metadata={'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3138508', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240202', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-05', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2207731', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220727', 'fr-bibliographic-data.invention-title': 'DISPOSITIF D’AÉRATION ESCAMOTABLE POUR UN SYSTÈME', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'PSA AUTOMOBILES SA', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': "2-10 Boulevard de l'Europe", 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'Poissy', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '78300', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'DE BEAUMONT', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'TANCREDE', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': 'None', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'SURESNES', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '92150', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.agents.agent.addressbook.orgname': 'None', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.address-1': 'None', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.city': 'None', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.postcode': 'None', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.country': 'None', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'STELLANTIS AUTO SAS', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': "2-10 boulevard de l'Europe", 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': 'POISSY', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': '78300', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country': 'FR', 'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'F24F  13/065       20220101AFI20220922BHFR        ', 'fr-bibliographic-data.language-of-filing': 'fr', 'fr-patent-life.references-cited.citation.patcit.text': 'DE 10 2004 060386 A1 (FAURECIA INNENRAUM\nSYS GMBH [DE]) 29 juin 2006 (2006- ...
#  Document(page_content='\n    L’invention concerne un ensemble électrique (1) configuré pour empêcher une ouverture intempestive d’un réseau électrique haute tension (RHT) d’un véhicule automobile, l’ensemble électrique (1) comportant une batterie électrique de traction (11) reliée au réseau électrique haute tension (RHT), au moins un contacteur (CT+, CT-) de sécurité configuré pour coupler ou découpler la batterie électrique de traction (11) au réseau électrique haute tension (RHT), un organe de sécurité (17) alimenté par la batterie électrique basse tension (15) et relié à l’au moins un contacteur (CT+, CT-) afin de contrôler une alimentation électrique de l’au moins un contacteur (CT+, CT-) pour autoriser une fermeture ou une ouverture du réseau électrique haute tension (RHT), et un dispositif électrique (16) configuré pour maintenir l’au moins un contacteur (CT+, CT-) fermé pendant une durée de référence en cas d’ouverture intempestive de l’organe de sécurité (17).\n    Figure 1 \n  ', metadata={'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3138561', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240202', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-05', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2207650', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220726', 'fr-bibliographic-data.invention-title': 'ENSEMBLE ELECTRIQUE POUR SECURISER UN RESEAU ELECTRIQUE HAUTE TENSION D’UN VEHICULE AUTOMOBILE ELECTRIFIE', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'PSA AUTOMOBILES SA', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': "2-10 Boulevard de l'Europe", 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'Poissy', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '78300', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'JEAN', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'KAMILLE', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': 'None', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'FONTAINEBLEAU', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '77300', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.agents.agent.addressbook.orgname': 'None', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.address-1': 'None', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.city': 'None', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.postcode': 'None', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.country': 'None', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'STELLANTIS AUTO SAS', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': "2-10 boulevard de l'Europe", 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': 'POISSY', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': '78300', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country': 'FR', 'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'B60L   3/00        20220101ALI20221005BHFR        ', 'fr-bibliographic-data.language-of-filing': 'fr ...
#  Document(page_content='\n    L’invention concerne un module lumineux (1) d’un dispositif d’éclairage et/ou de signalisation de véhicule automobile, comportant\xa0une OLED flexible (2) montée sur un substrat transparent (3) comportant une couche d’interconnexion électrique\xa0; un support (4) de OLED flexible agencé pour conformer au moins une partie de l’OLED flexible et le substrat transparent selon une forme prédéterminée, l’OLED flexible étant fixée au support au moyen d’un adhésif\xa0(51) ; une carte de circuit imprimé flexible (6) ; caractérisé en ce que le substrat transparent comporte une portion (32) dépassant de l’OLED et faisant face à une portion (43) du support, en ce que la carte de circuit imprimé flexible est reliée électriquement à la couche d’interconnexion au niveau de cette portion du substrat transparent et en ce que la carte de circuit imprimé flexible est fixée à cette portion du support au moyen d’un adhésif (52).\n    Figure à publier avec l’abrégé\xa0: Fig. 1\n  ', metadata={'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3138566', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240202', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-05', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2207972', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220801', 'fr-bibliographic-data.invention-title': 'Module lumineux intégrant une diode électroluminescente organique flexible', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'Valeo Vision', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': '34 RUE SAINT-ANDRÉ', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'BOBIGNY CEDEX', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '93012', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'Jimenez Rodriguez', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'Raul', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': 'None', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'BOBIGNY', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '93012', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.agents.agent.addressbook.orgname': 'AQUINOV', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.address-1': 'Allée de la forestière', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.city': 'Beychac et Caillau', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.postcode': '33750', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.country': 'FR', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'Valeo Vision', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': '34 RUE SAINT-ANDRÉ', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': 'BOBIGNY CEDEX', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': '93012', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country': 'FR', 'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'F21S  43/145       20220101ALI20221116BHFR        ', 'fr-bibliographic-data.language-of-filing': 'fr', 'fr- ...
#  Document(page_content="\n    L'invention concerne un distributeur rotatif hydraulique comportant un boîtier (2) et un noyau (4), ledit boîtier (2) comprenant une paroi latérale (8), deux parois d’extrémité (6, 10) délimitant une chambre hydraulique, dans laquelle est logé le noyau (4) apte à tourner dans ladite chambre autour d’un axe (XX’) de rotation, au moins un orifice d’alimentation (11), et au moins un orifice de sortie (12, 20), le noyau (4) comportant une surface latérale (32), une ouverture d’entrée (18), au moins une sortie latérale (34) et un conduit (38) ou une chambre qui relie l’ouverture d’entrée (18) et la sortie latérale et qui permet une alimentation de chacun desdits orifices de sortie (12, 20) en fonction de la position angulaire du noyau dans le boîtier, le noyau comportant en outre au moins un joint d’étanchéité inamovible, contre la surface latérale du noyau.\n    Figure pour l’abrégé\xa0: 1\n  ", metadata={'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3138488', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240202', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-05', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2207735', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220727', 'fr-bibliographic-data.invention-title': 'DISTRIBUTEUR A JOINT INCORPORE, ET PROCEDE DE REALISATION\xa0', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'Bontaz Centre R&D', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': 'Impasse des chênes Z.I des Valignons', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'MARNAZ', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '74460', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'MIRALLES', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'ERIC', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': 'None', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'ARENTHON', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '74800', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.agents.agent.addressbook.orgname': 'BREVALEX', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.address-1': '22 Avenue Doyen Louis Weil', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.city': 'GRENOBLE CEDEX 01', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.postcode': '38024', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.country': 'FR', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'Bontaz Centre R&D', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': 'Impasse des chênes Z.I des Valignons', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': 'MARNAZ', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': '74460', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country': 'FR', 'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'F16K   5/04        20220101AFI20220930BHFR        ', 'fr-bibliographic-data.language-of-filing': 'fr', 'fr-patent-life.references-cited.citation.patcit.text': 'DE  ...
#  Document(page_content='\n    La présente invention concerne un élément de cuisson revêtu (1) pour article culinaire ou appareil électrique de cuisson, comportant un substrat métallique (2) revêtu sur au moins une face (2a) par au moins les couches suivantes et dans cet ordre à partir du substrat métallique 2)\xa0:\n    (3a) sous-couche dure poreuse constituée d’une ou plusieurs polyétherarylcétones (PEAK) et leurs mélanges, éventuellement de charges, éventuellement moins de 3\xa0% en poids d’additifs par rapport au poids de ladite sous-couche dure et éventuellement moins de 3\xa0% en poids d’agent(s) colorant(s) par rapport au poids de ladite sous-couche dure, \n    (3b) éventuellement, une ou plusieurs couche(s) intermédiaire(s) constituée(s) d’un ou plusieurs agent(s) colorant(s) et éventuellement \n    d’une ou plusieurs résine(s) silicone, et/oud’un ou plusieurs polymère(s) thermoplastique(s) et/ou,d’une ou plusieurs charge(s), et/oud’un ou plusieurs additif(s)\n    (3c) une couche de finition constituée d’une ou plusieurs résine(s) silicone et éventuellement \n    d’un ou plusieurs polymère(s) thermoplastique(s), et/oud’une ou plusieurs charge(s), et/oud’un ou plusieurs additif(s), et/oude paillettes\xa0;\n    son procédé de fabrication, un article culinaire ou un appareil de cuisson le comprenant.\n  ', metadata={'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3138285', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240202', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-05', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2207865', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220729', 'fr-bibliographic-data.invention-title': 'Revêtement non-fluoré hybride PAEK/résine silicone', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'SEB S.A.', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': '112 chemin du Moulin Carron Campus SEB', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'ECULLY', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '69130', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'TANGUY', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'PERRINE', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': 'None', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'ECULLY CEDEX', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '69134', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.agents.agent.addressbook.orgname': 'REGIMBEAU', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.address-1': '20, rue de Chazelles', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.city': 'PARIS CEDEX 17', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.postcode': '75847', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.country': 'FR', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'SEB S.A.', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': '112 chemin du Moulin Carron Campus SEB', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': 'ECULLY', 'fr-bibliographic-data.fr- ...
#  Document(page_content="\n    Dispositif de surveillance d'opération industrielle\n    Un dispositif de surveillance d'opération industrielle comprend un carter (10) sensiblement étanche logeant une source d'acquisition d'images et/ou de vidéos\xa0(4) et un ordinateur (6). Le dispositif (2) est agencé pour déterminer des images de surveillance à partir de la source d'acquisition d'images et/ou de vidéos (4), l'ordinateur (6) est à refroidissement passif et est agencé pour exécuter une séquence d'apprentissage de normalité d'une scène d'un site d'opération industrielle à surveiller dont les données de sortie sont utilisées par une séquence de surveillance d'opération industrielle, l'ordinateur (6) est agencé, pour une scène donnée d'un site d'opération industrielle à surveiller, pour mettre en œuvre la séquence d'apprentissage de normalité en utilisant un réseau de neurones convolutif (8) pour réseau de neurones à transfert de style pré-entraîné et des images de surveillance tirées de ladite scène donnée et associées à une durée d'acquisition choisie en fonction de l'opération industrielle à surveiller, pour sélectionner comme données de sortie de la séquence d'apprentissage de normalité des matrices de référence tirées de certaines au moins des matrices de Gram d'au moins une couche de convolution dudit réseau de neurones (8) obtenues après le traitement de toutes les images de surveillance associées à la durée d'acquisition choisie, et l'ordinateur (6) est agencé, pour une scène donnée d'un site d'opération industrielle à surveiller, pour mettre en œuvre la séquence de surveillance en recevant des images de surveillance obtenues à partir de ladite scène donnée, en les fournissant audit réseau de neurones convolutif (8), et en retournant une valeur de surveillance indiquant une condition de normalité ou d'anormalité de ladite opération industrielle en fonction du traitement de ces images de surveillance par ledit réseau de neurones convolutif (8)et des données de sortie de la séquence d'apprentissage de normalité.\n  ", metadata={'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3138550', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240202', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-05', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2207938', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220729', 'fr-bibliographic-data.invention-title': "Dispositif de surveillance d'opération industrielle", 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'ERAMET', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': '10 boulevard de Grenelle', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'Paris', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '75015', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'BOCZSZUK', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'Pierre', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': 'None', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'Paris', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '75015', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'FR', 'fr-bibliographic-data.part ...
#  Document(page_content='\n    Procédé d’obtention d’une couronne métallique d’axe longitudinal, le procédé comprenant les étapes de\xa0:a) fourniture d’un anneau métallique (10) d’axe longitudinal (A), l’anneau (10) comprenant deux parois annulaires cylindriques radialement interne (12) et externe (14)\xa0;b) usinage des parois annulaires radialement interne (12) et externe (14) de manière à obtenir un renflement annulaire radialement interne (52) et un renflement annulaire radialement externe (62) ; c) réalisation d’un laminage circulaire droit sur lesdits renflements annulaires radialement interne (52) et externe (62).\n    Figure de l’abrégé\xa0: Figure 6\n  ', metadata={'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3138336', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240202', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-05', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2207755', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220728', 'fr-bibliographic-data.invention-title': 'Procédé d’obtention d’une couronne annulaire métallique', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'SAFRAN AIRCRAFT ENGINES', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': '2, boulevard du Général Martial Valin', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'PARIS', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '75015', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'LECONTE', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'Gilbert, Michel, Marin', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': 'None', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'MOISSY CRAMAYEL CEDEX', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '77550', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.agents.agent.addressbook.orgname': 'Ernest GUTMANN - Yves PLASSERAUD SAS', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.address-1': "Chez Plasseraud IP  66, rue de la Chaussée d'Antin", 'fr-bibliographic-data.parties.agents.agent.addressbook.address.city': 'PARIS', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.postcode': '75009', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.country': 'FR', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'SAFRAN AIRCRAFT ENGINES', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': '2, boulevard du Général Martial Valin', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': 'PARIS', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': '75015', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country': 'FR', 'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'B21D  53/16        20220101ALI20221031BHFR        ', 'fr-bibliographic-data.language-of-filing': 'fr', 'fr-patent-life.references-cited.citation.patcit.text': 'FR 3 017 060 A1 (SNECMA [FR])\n7 août 2015 (2015-08-07)', 'fr-patent-life.references-cited.citation.patcit.document-id.country': 'FR', 'fr-patent-life.references-cited.citation.patcit.docum ...
#  Document(page_content='\n    Cet ensemble de présentation à la vente de produits, destinés à être conservés à une température contrôlée, comprend au moins un étalage (1 – 4) et un système d’alimentation (7) en liquide, notamment en eau potable, comportant au moins une ligne d’alimentation (72 – 75) apte à être connectée avec une source (200) dudit liquide, en particulier un réseau d’eau potable. \n    Chaque ligne alimente un organe de diffusion de liquide (6), placé au-dessus de la zone de réception de l’étalage en vue de l’élimination de la couche de glace présente sur la zone de réception, alors que des moyens de commande (9, 90, 92 - 95) sont configurés pour alimenter le liquide uniquement pendant une durée prédéfinie.\n    L’invention permet d’éliminer, de manière simple et fiable, sensiblement la totalité de la glace présente sur les étalages, moyennant une intervention humaine limitée. De plus l’ensemble de présentation peut être mis en œuvre de manière commode et intuitive, intègre un nombre réduit d’éléments mécaniques en regard de l’existant, tout en ne générant pas d’encombrement supplémentaire significatif.\n    Figure pour l’abrégé\xa0: [Fig. 4]\n  ', metadata={'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3138277', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240202', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-05', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2207648', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220726', 'fr-bibliographic-data.invention-title': 'Ensemble de présentation de produits comprenant des moyens permettant d’éliminer la glace, et son procédé de mise en œuvre', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'ARECO FINANCES ET TECHNOLOGIE - ARFITEC', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': '114 chemin de Saint Marc', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'GRASSE', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '06130', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'GSCHWIND', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'Michel', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': 'None', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'PLACASSIER', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '06130', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.agents.agent.addressbook.orgname': 'IXAS CONSEIL', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.address-1': '22 avenue René Cassin', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.city': 'LYON', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.postcode': '69009', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.country': 'FR', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'ARECO FINANCES ET TECHNOLOGIE - ARFITEC', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': '114 chemin de Saint Marc', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': 'GRASSE', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': '0 ...
#  Document(page_content='\n    L’invention concerne une boite de réservation (1) adaptée pour ménager un volume de réception de câbles et conduits dans une paroi en béton d’un bâtiment, caractérisée en ce que la boite de réservation (1) est ouverte sur au moins une (2) de ses faces et adaptée pour être solidarisée de manière réversible à un organe de liaison (3) pourvu d’au moins une partie aimantée, ladite partie aimanté étant adaptée pour réaliser une liaison magnétique amovible avec une zone métallique d’au moins un élément de coffrage de ladite paroi en béton du bâtiment.\n    Figure à publier avec l’abrégé\xa0: Fig. 1 \n  ', metadata={'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3138460', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240202', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-05', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2207726', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220727', 'fr-bibliographic-data.invention-title': 'BOITE DE RESERVATION POURVUE D’UNE PARTIE AIMANTEE', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'SIIB FRANCE', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': '7 Rue des Acilloux', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': "COURNON-D'AUVERGNE", 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '63800', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'AUCOUTURIER', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'René', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': 'None', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'CHATEL-GUYON', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '63140', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.agents.agent.addressbook.orgname': 'ABSAROKA', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.address-1': '5 Chemin sous Vignoux', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.city': "BEAUREGARD L'EVEQUE", 'fr-bibliographic-data.parties.agents.agent.addressbook.address.postcode': '63116', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.country': 'FR', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'SIIB FRANCE', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': '7 Rue des Acilloux', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': "COURNON-D'AUVERGNE", 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': '63800', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country': 'FR', 'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'E04G  15/06        20220101AFI20220921BHFR        ', 'fr-bibliographic-data.language-of-filing': 'fr', 'fr-patent-life.references-cited.citation.patcit.text': 'FR 2 754 291 A1 (ALOMBARD SA [FR])\n10 avril 1998 (1998-04-10)', 'fr-patent-life.references-cited.citation.patcit.document-id.country': 'FR', 'fr-patent-life.references-cited.citation.patcit.document-id.doc-number': 'FR-2754291-A1', 'fr-patent-life.references-cited.citation.patcit.document-id.date': '19980410', 'fr-patent-life.fr- ...
#  Document(page_content='\n    L’invention concerne un système de détection de colmatage d’un clapet antiretour amont (V1) d’un moteur thermique de véhicule automobile.\n    Le moteur thermique comprend\xa0:- une valve de régulation de pression (RV) dans un déshuileur (D) d’une culasse (C2)\xa0;- un clapet antiretour amont (V1) disposé dans le déshuileur (D), au niveau d’un retour interne (R) vers un tube d’admission (TA),- un clapet antiretour aval (V2) connecté à une ligne secondaire de ventilation des gaz (LG) issue de la culasse (C2).\n    Selon l’invention, le système de détection comprend\xa0:- un premier et un deuxième capteurs de pression absolue (AP1, AP2) respectivement pour l’amont du carter (C1) et la culasse (C2).\n    Le diagnostic de blocage est fait sur la base des pressions des capteurs (AP1, AP2), et d’une perte de charge.\n    L’invention concerne également un procédé et véhicule sur la base d’un tel système.\n    Figure 1\n  ', metadata={'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3138475', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240202', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-05', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2207859', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220729', 'fr-bibliographic-data.invention-title': 'SYSTEME ET PROCEDE DE DETECTION DE COLMATAGE D’UN CLAPET ANTIRETOUR DE CHARGE PARTIELLE D’UN MOTEUR THERMIQUE, VEHICULE COMPRENANT UN TEL SYSTEME', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'PSA AUTOMOBILES SA', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': "2-10 Boulevard de l'Europe", 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'Poissy', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '78300', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'KEIM', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'MARION', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': 'None', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'VOISINS LE BRETONNEUX', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '78960', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.agents.agent.addressbook.orgname': 'None', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.address-1': 'None', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.city': 'None', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.postcode': 'None', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.country': 'None', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'STELLANTIS AUTO SAS', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': "2-10 boulevard de l'Europe", 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': 'POISSY', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': '78300', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country': 'FR', 'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'F02D  41/14        20220101ALI20221010BHFR        ', 'fr-bibliographic-data.language-of-filing':  ...

# %%
mistral_model = "mistral-large-latest"

# %%
### Retrieval Grader

from langchain_mistralai import ChatMistralAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field

# Data model
class GradeDocuments(BaseModel):
    """Binary score for relevance check on retrieved documents."""

    binary_score: str = Field(description="Documents are relevant to the question, 'yes' or 'no'")

# LLM with function call
llm = ChatMistralAI(model=mistral_model, temperature=0)
structured_llm_grader = llm.with_structured_output(GradeDocuments)

# Prompt
system = """You are a grader assessing relevance of a retrieved document to a user question. \n
    If the document contains keyword(s) or semantic meaning related to the question, grade it as relevant. \n
    Give a binary score 'yes' or 'no' score to indicate whether the document is relevant to the question."""
grade_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system),
        ("human", "Retrieved document: \n\n {document} \n\n User question: {question}"),
    ]
)

retrieval_grader = grade_prompt | structured_llm_grader
question = "air"
docs = retriever.invoke(question, n=2)
print(len(docs))
doc_txt = docs[1].page_content
print(doc_txt)
print(retrieval_grader.invoke({"question": question, "document": doc_txt}))
# Out:
# 10
# Fig.2
# binary_score='no'

# %%
### Generate ? after retrieved documents ?

from langchain_core.output_parsers import StrOutputParser

# Prompt
system = """You are a professional pattent attorney. \n
    You will be given a user question and a list of relevant patent descriptions. \n
    Explain clearly in what way each patent is related to the user question."""

generate_patent_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system),
        ("user", "User question: \n\n {question} \n\n Documents: {context}"),
    ]
)
# LLM
llm = ChatMistralAI(model=mistral_model, temperature=0)

# Chain
patent_rag_chain = generate_patent_prompt | llm | StrOutputParser()

# Run
patent_generation = patent_rag_chain.invoke({"question": question, "context": docs})
print(patent_generation)
# Out:
# I'm sorry for any confusion, but the user question provided is quite broad. The term "air" could be related to a wide range of patents, including but not limited to air conditioning systems, air purification systems, air compression technologies, and more.
#
# Without a more specific context or query, it's challenging to provide a detailed analysis of how each patent is related to the user question. However, I'll do my best to provide a general overview:
#
# 1. The first patent (FR3138358) is titled "SYSTEME DE MONTAGE D’UNE BATTERIE D’ALIMENTATION D’UN MOTEUR DE VEHICULE AUTOMOBILE A PROPULSION ELECTRIQUE" which translates to "SYSTEM FOR MOUNTING A BATTERY FOR SUPPLYING AN ELECTRIC VEHICLE ENGINE". This patent might be indirectly related to air if the electric vehicle uses an air cooling system for its battery.
#
# 2. The second patent (FR3138074) is titled "VEHICULE AUTOMOBILE COMPORTANT UN SYSTEME DE CHARGE POUR BATTERIE" which translates to "VEHICLE HAVING A BATTERY CHARGING SYSTEM". Similar to the first patent, this could be indirectly related to air if the charging system uses air cooling.
#
# 3. The third patent (FR3137967) is titled "Procédés et systèmes de caractérisation optique d’un milieu volumique et diffusant" which translates to "Processes and systems for optical characterization of a volumetric and scattering medium". This patent could be related to air if the system is used to analyze air quality or air particles.
#
# 4. The fourth patent (FR3137769) is titled "Procédé de sauvegarde de données personnelles sensibles sur une chaîne de blocs" which translates to "Process for backing up sensitive personal data on a blockchain". This patent doesn't seem directly related to air.
#
# 5. The fifth patent (FR3137818) is titled "Article présentant un système de serrage autour d’une zone corporelle d’un utilisateur" which translates to "Article presenting a tightening system around a body area of a user". This patent doesn't seem directly related to air.
#
# 6. The sixth patent (FR3137644) is titled "SURVEILLANCE MULTI-CONDITIONS D’UNE FONCTION DE STATIONNEMENT AUTOMATIQUE D’UN VÉHICULE" which translates to "MULTI-CONDITION MONITORING OF AN AUTOMATIC PARKING FUNCTION OF A VEHICLE". This patent doesn't seem directly related to air.
#
# 7. The seventh patent (FR3137640) is titled "PROCEDE DE CONTROLE D’UN REGIME MOTEUR ET PROCEDE DE PILOTAGE D’UN GROUPE DE CLIMATISATION SELON LE PROCEDE DE CONTROLE" which translates to "METHOD FOR CONTROLLING AN ENGINE SPEED AND METHOD FOR CONTROLLING AN AIR CONDITIONING GROUP ACCORDING TO THE CONTROL METHOD". This patent is directly related to air as it involves air conditioning systems.
#
# 8. The eighth patent (FR3137812) is titled "Antenne d’émission à rayons X comprenant une pluralité de sources de rayons X" which translates to "X-ray emission antenna comprising a plurality of X-ray sources". This patent doesn't seem directly related to air.
#
# 9. The ninth patent (FR3138288) is titled "Unité de nettoyage pour tête d’aspiration" which translates to "Cleaning unit for suction head". This patent could be indirectly related to air if the suction head is used in a vacuum cleaner that improves air quality.
#
# 10. The tenth patent (FR3137708) is titled "ACTIONNEUR POUR L’ENTRAINEMENT D’UN ECRAN" which translates to "ACTUATOR FOR DRIVING A SCREEN". This patent doesn't seem directly related to air.

# %%
# Post-processing
def format_docs(docs):
    joined = "\n\n".join(doc.page_content for doc in docs)
    docs_metadata = [doc.metadata for doc in docs]
    return (joined, docs_metadata)

# %%
### Generate ? after retrieved documents ?

from langchain_core.output_parsers import StrOutputParser

# Prompt
system = """You are a professional pattent attorney. \n
    You will be given a user question and a web search result related to the question. \n
    Explain clearly how the web result can help answer the user question."""

generate_web_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system),
        ("user", "User question: \n\n {question}"),
    ]
)
# LLM
llm = ChatMistralAI(model=mistral_model, temperature=0)

# Chain
web_rag_chain = generate_web_prompt | llm | StrOutputParser()

# Run
web_generation = web_rag_chain.invoke({"question": question})
print(web_generation)
# Out:
# I'm sorry for the incomplete user question. However, I'll assume you're asking about air patents or patenting an invention related to air.
#
# Web search result: "USPTO - Patent Process Overview"
#
# The web search result provides an overview of the patent process from the United States Patent and Trademark Office (USPTO). This resource can help answer the user question by providing a step-by-step guide on how to apply for a patent, which is essential for any invention, including those related to air.
#
# The overview covers the following key steps:
#
# 1. Determining whether the invention is patentable: This step involves understanding the criteria for patentability and conducting a patent search to ensure the invention is novel and non-obvious.
#
# 2. Preparing and submitting an initial application: The applicant must provide a detailed description of the invention, including drawings if necessary, and submit it to the USPTO.
#
# 3. Patent application review: A patent examiner reviews the application to determine if the invention meets the patentability requirements.
#
# 4. Responding to USPTO office actions: If the examiner finds any issues with the application, the applicant must address them and submit a response.
#
# 5. Receiving a patent grant or denial: If the examiner approves the application, the USPTO will issue a patent. If not, the applicant can appeal the decision or amend the application.
#
# This information can help the user understand the patent process and what to expect when attempting to patent an invention related to air. Additionally, the USPTO website offers more resources and guidance on specific types of inventions and patents, which may be helpful for the user's particular situation.

# %%
from langchain_community.tools.tavily_search import TavilySearchResults
web_search_tool = TavilySearchResults(k=3)

# %%
from langchain_core.prompts import ChatPromptTemplate

system = """You are a professional technical translator translating an English user query to French. \n
Reply only with the French translation. \n
Note that the question you are given is related to the patent industry.
"""

translation_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system),
        ("human", "User question: {question}"),
    ]
)

translator_chain = translation_prompt | llm | StrOutputParser()

# %%
from typing_extensions import TypedDict
from typing import List

class GraphState(TypedDict):
    """
    Represents the state of our graph.

    Attributes:
        question: question
        generation: LLM generation
        web_search: whether to add search
        documents: list of documents
    """
    question : str
    generation : str
    web_search : str
    documents : List[str]
    metadata:

# %%
docs_metadata = None

### Nodes

def translate(state):
    print("---TRANSLATING---")
    question = state["question"]

    translation = translator_chain.invoke({"question": question})
    state["question"] = translation

    return state


def retrieve(state):
    """
    Retrieve documents from vectorstore

    Args:
        state (dict): The current graph state

    Returns:
        state (dict): New key added to state, documents, that contains retrieved documents
    """
    print("---RETRIEVE---")
    question = state["question"]

    # Retrieval
    documents = retriever.invoke(question)

    return {"documents": documents, "question": question}

def generate(state):
    """
    Generate answer using RAG on retrieved documents

    Args:
        state (dict): The current graph state

    Returns:
        state (dict): New key added to state, generation, that contains LLM generation
    """
    print("---GENERATE---")
    question = state["question"]
    documents = state["documents"]

    global docs_metadata

    if state["web_search"] == "Yes":
        generation = web_rag_chain.invoke({"context": documents, "question": question})
    else:
        generation = patent_rag_chain.invoke({"context": documents, "question": question})

    documents, docs_metadata = format_docs(documents)
    docs_metadata = docs_metadata

    state["documents"] = documents
    state["generation"] = generation

    return state

def grade_documents(state):
    """
    Determines whether the retrieved documents are relevant to the question
    If any document is not relevant, we will set a flag to run web search

    Args:
        state (dict): The current graph state

    Returns:
        state (dict): Filtered out irrelevant documents and updated web_search state
    """

    print("---GRADE DOCUMENTS---")
    question = state["question"]
    documents = state["documents"]

    # Score each doc
    filtered_docs = []
    web_search = "Yes"
    for d in documents:
        score = retrieval_grader.invoke({"question": question, "document": d.page_content})
        grade = score.binary_score
        # Document relevant
        if grade.lower() == "yes":
            print("---GRADE: DOCUMENT RELEVANT---")
            filtered_docs.append(d)
            web_search = "No"
        else:
            print("---GRADE: DOCUMENT NOT RELEVANT---")
    return {"documents": filtered_docs, "question": question, "web_search": web_search, "metadata": ""}

def web_search(state):
    """
    Web search based based on the question

    Args:
        state (dict): The current graph state

    Returns:
        state (dict): Appended web results to documents
    """

    print("---WEB SEARCH---")
    question = state["question"]
    documents = state["documents"]

    # Web search
    docs = web_search_tool.invoke({"query": question})

    web_results = "\n".join([d["content"] for d in docs])
    web_sources = [d["url"] for d in docs]

    web_results = Document(page_content=web_results, metadata={"sources": web_sources})

    if documents is not None:
        documents.append(web_results)
    else:
        documents = [web_results]

    return {"documents": documents, "question": question}

### Edges

def decide_to_generate(state):
    """
    Determines whether to generate an answer, or add web search

    Args:
        state (dict): The current graph state

    Returns:
        str: Binary decision for next node to call
    """

    print("---DECIDE TO GENERATE---")
    web_search = state["web_search"]

    if web_search == "Yes":
        # All documents have been filtered check_relevance
        # We will re-generate a new query
        print("---DECISION: ALL DOCUMENTS ARE NOT RELEVANT TO QUESTION, INCLUDE WEB SEARCH---")
        return "websearch"
    else:
        # We have relevant documents, so generate answer
        print("---DECISION: GENERATE---")
        return "generate"

# %%
from langgraph.graph import END, StateGraph

workflow = StateGraph(GraphState)

# Define the nodes
workflow.add_node("translate", translate)  # translate
workflow.add_node("retrieve", retrieve)  # retrieve
workflow.add_node("grade_documents", grade_documents) # grade documents
workflow.add_node("generate", generate)  # generate
workflow.add_node("websearch", web_search)  # web search

# Build graph
workflow.set_entry_point("translate")
workflow.add_edge("translate", "retrieve")
workflow.add_edge("retrieve", "grade_documents")
workflow.add_conditional_edges(
    "grade_documents",
    decide_to_generate,
    {
        "websearch": "websearch",
        "generate": "generate",
    },
)
workflow.add_edge("websearch", "generate")
workflow.add_edge("generate", END)

# Compile
app = workflow.compile()

# %%
from pprint import pprint
inputs = {"question": "Do you know anything about patents regarding farming?"}
for output in app.stream(inputs):
    for key, value in output.items():
        pprint(f"Finished running: {key}:")
pprint(value["generation"])
# Out:
# ---TRANSLATING---
# 'Finished running: translate:'
# ---RETRIEVE---
# 'Finished running: retrieve:'
# ---GRADE DOCUMENTS---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---DECIDE TO GENERATE---
# ---DECISION: GENERATE---
# 'Finished running: grade_documents:'
# ---GENERATE---
# 'Finished running: generate:'
# ('The provided documents do not seem to be directly related to agriculture. '
#  'However, I will explain the main subject of each patent for better '
#  'understanding.\n'
#  '\n'
#  '1. Document with invention title "SKI ALPIN A LIGNE DE COTE AMELIOREE" '
#  '(Improved alpine ski sidecut):\n'
#  'This patent is about an improved design for alpine skis. The focus is on '
#  'enhancing the sidecut of the ski to improve its performance. This patent is '
#  'not related to agriculture.\n'
#  '\n'
#  '2. Document with invention title "Dispositif et Procédé de détermination de '
#  'l’état d’assemblage d’une extrémité filetée" (Device and method for '
#  'determining the assembly state of a threaded end):\n'
#  'This patent is about a device and method to determine the assembly state of '
#  'a threaded end, which can be used in various industries like manufacturing, '
#  'automotive, or aerospace. This patent is not directly related to '
#  'agriculture.\n'
#  '\n'
#  'If you have any other patents or need further clarification, please let me '
#  'know.')

# %%
print(value["generation"])
# Out:
# The provided documents do not seem to be directly related to agriculture. However, I will explain the main subject of each patent for better understanding.
#
# 1. Document with invention title "SKI ALPIN A LIGNE DE COTE AMELIOREE" (Improved alpine ski sidecut):
# This patent is about an improved design for alpine skis. The focus is on enhancing the sidecut of the ski to improve its performance. This patent is not related to agriculture.
#
# 2. Document with invention title "Dispositif et Procédé de détermination de l’état d’assemblage d’une extrémité filetée" (Device and method for determining the assembly state of a threaded end):
# This patent is about a device and method to determine the assembly state of a threaded end, which can be used in various industries like manufacturing, automotive, or aerospace. This patent is not directly related to agriculture.
#
# If you have any other patents or need further clarification, please let me know.

# %%
print(docs_metadata)
# Out:
# [{'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'A63C   5/04        20220101AFI20220914BHFR        ', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220720', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2207412', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': '98 rue Louis BARRAN', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': 'SAINT-JEAN-DE-MOIRANS', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country': 'FR', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': '38430', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'SKIS ROSSIGNOL', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240126', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3138044', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-04', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.invention-title': 'SKI ALPIN A LIGNE DE COTE AMELIOREE', 'fr-bibliographic-data.language-of-filing': 'fr', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.address-1': 'Le Contemporain 50 chemin de la bruyère', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.city': 'DARDILLY', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.postcode': '69570', 'fr-bibliographic-data.parties.agents.agent.addressbook.orgname': 'LAURENT & CHARRAS', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': '98 rue Louis BARRAN', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'SAINT-JEAN-DE-MOIRANS', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '38430', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'SKIS ROSSIGNOL', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': 'None', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'COUBLEVIE', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '38500', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'Romain', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'BAILLY', 'fr-patent-life.fr-date-availability.fr-date-search-completed.date': '20240126', 'fr-patent-life.fr-date-availability.fr-date-search-completed.fr-bopinum': '2024-04', 'fr-patent-life.fr-date-availability.fr-last-fee-payement.date': '20230728', 'fr-patent-life.fr-date-availability.fr-next-fee-payement.date': '20240731', 'fr-patent-life.references-cited.citation.patcit.document-id.country': 'None', 'fr-patent-life.references-cited.citation.patcit.document-id.date': 'None', 'fr-patent-life.references-cited.citation.patcit.document-id.doc-number': 'None', 'fr-patent-life.references-cited.citation.patcit.text': 'None'}, {'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'G01M   3/00        20220101AFI20221014BHFR        ', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220718', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2207318', 'fr-bibliographic-data.fr-owners.fr-o ...

# %%
def extract_sources(metadata):
    # TODO...
    pass

# %%
# %pip install -qU mistralai langchain-core langchain langchain-mistralai gradio
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-auth 2.19.1 requires urllib3<2.0, but you have urllib3 2.2.1 which is incompatible.
# poetry 1.3.2 requires urllib3<2.0.0,>=1.26.0, but you have urllib3 2.2.1 which is incompatible.
# socid-extractor 0.0.23 requires python-dateutil>=2.8.1, but you have python-dateutil 2.7.3 which is incompatible.
# transformers 4.35.0 requires tokenizers<0.15,>=0.14, but you have tokenizers 0.19.1 which is incompatible.
# Note: you may need to restart the kernel to use updated packages.

# %%
import gradio as gr
import time
from pprint import pprint

from mistralai.models.chat_completion import ChatMessage
model = "mistral-large-latest"

# Define the custom function to process the user input

# Progress statuses
statuses = [
    "step I success",
    "step II success",
    "step III failure",
    "step III success",
    "step IV success",
    "step V success"
]

# Function to simulate processing steps
def process(): # TODO...
    for i in range(len(statuses) + 1):
        time.sleep(0.5)
        yield '\n'.join(statuses[0:i])


def answer(history):
    inputs = {"question": history[-1][0]}
    msg = ""
    context = ""
    for output in app.stream(inputs):
        for key, value in output.items():
            if "generate" == key:
                continue   # dirty just not showing outcome from generate graph node
            # print(value)
            pprint(f"Finished running: {key}:")
            msg += f"\nFinished running: {key}:"
            yield msg
        if 'retrieve' in output and 'documents' in output['retrieve']:
            print('retrieved docs')
            print(output['retrieve']['documents'])
            msg += f" ({len(output['retrieve']['documents'])} docs)"
            context += str(output['retrieve']['documents'])
            yield msg
        if 'websearch' in output and 'documents' in output['websearch']:
            print('websearch results')
            print(output['websearch']['documents'])
            msg += f" ({len(output['websearch']['documents'])} results)"
            context += str(output['websearch']['documents'])
            yield msg
    history[-1][0] += f"considering `{context}`"
    # response = value["generation"]
    # return history[:-1] + [[history[-1][1], response]]  # Update the last entry with the response

# Define the bot function to update the history with bot response
def bot(history):
    history_langchain_format = []

    # Convert the history to the format expected by the ChatMistralAI client
    for entry in history:
        if len(entry) == 2:
            human, ai = entry
            history_langchain_format.append(ChatMessage(role="user", content=human))
            if ai is not None:
                history_langchain_format.append(ChatMessage(role="assistant", content=ai))

    from mistralai.client import MistralClient
    client = MistralClient()
    response = client.chat_stream(
        model=model,
        messages=history_langchain_format,
    )

    history[-1][1] = ""
    for chunk in response:
        if chunk.choices[0].delta.content is not None:
            history[-1][1] += chunk.choices[0].delta.content
            yield history

# Function to handle user message submission
def user(user_message, history):
    history.append([user_message, None])
    return "", history

# Gradio interface
with gr.Blocks(theme=gr.themes.Glass()) as demo:
    progress_textbox = gr.Textbox(interactive=False, visible=True, autoscroll=True, show_label=False)
    chatbot = gr.Chatbot(show_label=False)
    msg = gr.Textbox(show_label=False, placeholder="Type your message here...")
    clear = gr.Button("Clear")

    # Action steps
    action_step = msg.submit(
        user, [msg, chatbot], [msg, chatbot], queue=False
    ).then(
        lambda: "", None, progress_textbox, queue=False  # Clear progress_textbox before showing new progress
    # ).then(
    #     process, None, progress_textbox
    ).then(
        answer, [chatbot], progress_textbox
    ).then(
        bot, chatbot, chatbot
    )

    # Clear button functionality
    clear.click(lambda: None, None, chatbot, queue=False).then(
        lambda: None, None, progress_textbox, queue=False  # Clear progress_textbox
    )

# Launch the Gradio app
demo.queue()
demo.launch(share=True, debug=True)
# Out:
# Running on local URL:  http://127.0.0.1:7861
# Running on public URL: https://a5901e0ab703ebec38.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://a5901e0ab703ebec38.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ---TRANSLATING---
# 'Finished running: translate:'
# ---RETRIEVE---
# 'Finished running: retrieve:'
# retrieved docs
# [Document(page_content='«\xa0Détecteur thermique de rayonnement\xa0»', metadata={'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'G01J   5/20        20220101ALI20221123BHFR        ', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220801', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2207983', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': '3 rue Michel Ange', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': 'PARIS', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country': 'FR', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': '75016', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240202', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3138516', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-05', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.invention-title': 'Détecteur thermique de rayonnement', 'fr-bibliographic-data.language-of-filing': 'fr', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.address-1': 'CABINET HAUTIER  20 RUE de la Liberté', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.city': 'NICE', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.postcode': '06000', 'fr-bibliographic-data.parties.agents.agent.addressbook.orgname': 'CABINET HAUTIER', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': '3 rue Michel Ange', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'PARIS', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '75016', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': 'None', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'VIF', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '38450', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'Gaël', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'MOIROUX', 'fr-patent-life.fr-date-availability.fr-date-search-completed.date': '20240202', 'fr-patent-life.fr-date-availability.fr-date-search-completed.fr-bopinum': '2024-05', 'fr-patent-life.fr-date-availability.fr-last-fee-payement.date': '20230828', 'fr-patent-life.fr-date-availability.fr-next-fee-payement.date': '20240902', 'fr-patent-life.references-cited.citation.patcit.document-id.country': 'WO', 'fr-patent-life.references-cited.citation.patcit.document-id.date': '20040318', 'fr-patent-life.references-cited.citation.patcit.document-id.doc-number': 'WO-2004023087-A1', 'fr-patent-life.references-cited.citation.patcit.text': 'WO 2004/023087 A1 (ROSEMOUNT AEROSPACE INC\n[US]) 18 mars 2004 (2004-03-18)'}), Document(page_content='Système respiratoire, notamment pour un aéronef, comprenant\xa0:', metadata={'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'A62B  18/02        20220101ALI20221213BHFR        ', 'fr- ...
# ---GRADE DOCUMENTS---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---DECIDE TO GENERATE---
# ---DECISION: ALL DOCUMENTS ARE NOT RELEVANT TO QUESTION, INCLUDE WEB SEARCH---
# 'Finished running: grade_documents:'
# ---WEB SEARCH---
# 'Finished running: websearch:'
# websearch results
# [Document(page_content="Brevet d'Aptitude de Pilote à Distance (BAPD) Le BAPD est obtenu après la réussite de l'examen OPEN.A2, associé à l'examen A1/A3 et une auto-formation pratique. Ce brevet est spécifique aux drones de classe C2, permettant de piloter à proximité des personnes et au-dessus de zones denses comme les quartiers résidentiels, commerciaux et ...\nS'il y a encore un débat entre le fait de dire que « télépilote de drone » n'est pas un métier mais une compétence, nous allons parcourir aujourd'hui les différents usages à travers 10 secteurs regroupant les métiers du drone, ouvrant ainsi de nouvelles perspectives de carrière dans l'industrie aérienne. 1.\nRecherche d'emploi. Ingénieur. Métiers d'avenir. Aéronautique - espace. Piloter, concevoir ou traiter les données : de nombreuses compétences gravitent autour des drones, qui n'ont rien de ...\nC'est grâce à cette formation que vous pourrez prétendre devenir pilote de drone professionnel. Depuis le 1er juillet 2018 la loi a changé et a entraîné des modifications du brevet technique. Voici les modifications : Pour accéder au brevet télépilote drone et débuter une formation, vous devez avoir 16 ans révolus. Par ailleurs, si ...\nLe Brevet d'Initiation au Métiers du Drone - BIMD - répond à une demande d'initiation de plus en plus importante du public. Aussi le certificat délivré permet aux personnes détentrices de valoriser dans leur CV leurs connaissances dans un nouveau monde qu'est le drone.", metadata={'sources': ['https://prepa-drone.fr/actualites/comprendre-examen-drone-a2', 'https://www.droneu.fr/les-metiers-du-drone/', 'https://www.letudiant.fr/metiers/les-metiers-qui-recrutent/autour-des-drones-quels-metiers-d-avenir.html', 'https://lesdroners.fr/univers-drone/formation-drone/', 'https://www.campus-aeronautique.com/vie-du-campus/bimd/']})]
# ---GENERATE---
# ---TRANSLATING---
# 'Finished running: translate:'
# ---RETRIEVE---
# 'Finished running: retrieve:'
# retrieved docs
# [Document(page_content='Dispositif  pour produire de l’énergie\xa0 à partir de nappe d’eau telle que lac, rivière, mer, nappe souterraine.. pompée à une température initiale, surchauffée par le soleil par un système solaire thermique (4) pour être transformée partiellement ou totalement en vapeur ,  permettant l’entraînement d’une turbine (6).', metadata={'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'F03B   1/00        20220101ALI20221117BHFR        ', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220725', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2207613', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': '1 rue pierre et marie curie', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': 'Epron', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country': 'FR', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': '14610', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'None', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240126', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3138168', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-04', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.invention-title': 'Centrale Hydro-solaire-vapeur-électrique', 'fr-bibliographic-data.language-of-filing': 'fr', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.address-1': '7 chemin du mont desert', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.city': 'esquay sur seulles', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.postcode': '14400', 'fr-bibliographic-data.parties.agents.agent.addressbook.orgname': 'None', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': '1 rue pierre et marie curie', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'Epron', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '14610', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'None', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': 'None', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'esquay sur seulles', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '14400', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'Pierre', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'lecanu', 'fr-patent-life.fr-date-availability.fr-date-search-completed.date': '20240126', 'fr-patent-life.fr-date-availability.fr-date-search-completed.fr-bopinum': '2024-04', 'fr-patent-life.fr-date-availability.fr-last-fee-payement.date': '20221121', 'fr-patent-life.fr-date-availability.fr-next-fee-payement.date': '20240731', 'fr-patent-life.references-cited.citation.patcit.document-id.country': 'US', 'fr-patent-life.references-cited.citation.patcit.document-id.date': '19600628', 'fr-patent-life.references-cited.citation.patcit.document-id.doc-number': 'US-2942411-A', 'fr-patent-life.references-cited.citation.patcit.text': 'US 2 942 411 A (HUTCHINGS LE ROI E)\n28 juin 1960 (1960-06-28)'}), Document(page_cont ...
# ---GRADE DOCUMENTS---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---DECIDE TO GENERATE---
# ---DECISION: ALL DOCUMENTS ARE NOT RELEVANT TO QUESTION, INCLUDE WEB SEARCH---
# 'Finished running: grade_documents:'
# ---WEB SEARCH---
# 'Finished running: websearch:'
# websearch results
# [Document(page_content="Il existe en tout plus de 15,2 millions de familles de brevets actifs, une famille étant un ensemble de brevets liés à une même invention. Plus de 4,7 millions de familles de brevets sont déjà liées à ces objectifs. L'Assemblée générale des Nations Unies a établi les objectifs de développement durable en 2015.\nDécouvrez comment des brevets innovants garantissent un accès en eau potable à tout le monde. Dans un monde confronté à de nombreux défis, l'innovation représente une lueur d'espoir. Les technologies cherchant à répondre à la crise mondiale de l'eau, qui prend de plus en plus d'importance, sont particulièrement source d'espoir.\nL'un des axes principaux de la recherche est la diminution des émissions de CO 2. Le secteur du transport dépose énormément de demandes de brevet en ce sens. Ces brevets verts constituent un atout : ils font sauter les blocages, notamment auprès des investisseurs qui ont ainsi la garantie que les entreprises continueront à générer des ...\nAfin de vous aider, l'INPI met à votre disposition une base de données regroupant les demandes de brevet français, européens, internationales PCT et certificat complémentaire de protection. Cette vérification est la première étape indispensable avant de déposer un brevet en France. Vous pourrez y retrouver les noms des déposants, le ...\nTéléchargements. Le brevet, un instrument de valorisation de la recherche et développement (PDF, 493.83 Ko) Les Thémas de la DGE. Innovation. Mis à jour le 20/12/2023. Le brevet joue un rôle central pour soutenir l'innovation en protégeant les inventeurs du risque d'imitation.", metadata={'sources': ['https://www.wipo.int/wipo_magazine_digital/fr/2024/article_0008.html', 'https://www.epo.org/fr/searching-for-patents/helpful-resources/patent-knowledge-news/linnovation-arrive-par-vagues-des', 'https://fr.planet-future.be/innovation/le-brevet-un-moteur-de-linnovation-ecologique/', 'https://www.inpi.fr/base-brevets', 'https://www.entreprises.gouv.fr/fr/etudes/themas-de-la-dge/brevet-recherche-developpement']})]
# ---GENERATE---
# ---TRANSLATING---
# 'Finished running: translate:'
# ---RETRIEVE---
# 'Finished running: retrieve:'
# retrieved docs
# [Document(page_content='L’invention concerne un système électrique (1702) comportant\xa0:', metadata={'fr-bibliographic-data.classifications-ipcr.classification-ipcr.text': 'H02M   7/00        20220101ALI20220928BHFR        ', 'fr-bibliographic-data.fr-application-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-application-reference.document-id.date': '20220630', 'fr-bibliographic-data.fr-application-reference.document-id.doc-number': '2206652', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.address-1': '14 Avenue des Beguines', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.city': 'Cergy', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.country': 'FR', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.address.postcode': '95800', 'fr-bibliographic-data.fr-owners.fr-owner.addressbook.orgname': 'Valeo Siemens eAutomotive France SAS', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.country': 'FR', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.date': '20240105', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.doc-number': '3137532', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.document-id.kind': 'A1', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-bopinum': '2024-01', 'fr-bibliographic-data.fr-publication-data.fr-publication-reference.fr-nature': 'Demande française', 'fr-bibliographic-data.invention-title': 'SYSTEME ELECTRIQUE AVEC CIRCUIT DE REFROIDISSEMENT D’UN MODULE DE PUISSANCE', 'fr-bibliographic-data.language-of-filing': 'fr', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.address-1': '14 Avenue des Beguines', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.city': 'Cergy', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.agents.agent.addressbook.address.postcode': '95800', 'fr-bibliographic-data.parties.agents.agent.addressbook.orgname': 'Valeo Siemens eAutomotive France SAS - Service Propriété Intellectuelle', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.address-1': '14 Avenue des Beguines', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.city': 'Cergy', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.address.postcode': '95800', 'fr-bibliographic-data.parties.applicants.applicant.addressbook.orgname': 'Valeo Siemens eAutomotive France SAS', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.address-1': 'None', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.city': 'Cergy', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.country': 'FR', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.address.postcode': '95800', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.first-name': 'David', 'fr-bibliographic-data.parties.inventors.inventor.addressbook.last-name': 'GILET', 'fr-patent-life.fr-date-availability.fr-date-search-completed.date': '20240105', 'fr-patent-life.fr-date-availability.fr-date-search-completed.fr-bopinum': '2024-01', 'fr-patent-life.fr-date-availability.fr-last-fee-payement.date': '20230622', 'fr-patent-life.fr-date-availability.fr-next-fee-payement.date': '20240701', 'fr-patent-life.references-cited.citation.patcit.document-id.country': 'EP', 'fr-patent-life.references-cited.citation.patcit.document-id.date': '20190123', 'fr-patent-life.references-cited.citation.patcit.document-id.doc-number': 'EP-3432694-A1', 'fr-patent-life.references-cited.citation.patcit.text': 'EP 3 432 694 A1 (VALEO EQUIP ELECTR MOTEUR\n[FR]) 23 janvier 2019 (2019-01-23)'}), Document(page_content='batterie et des moyens de génération d’au moins un signal sur la base desdites informations.', metadata={'f ...
# ---GRADE DOCUMENTS---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---DECIDE TO GENERATE---
# ---DECISION: GENERATE---
# 'Finished running: grade_documents:'
# ---GENERATE---
